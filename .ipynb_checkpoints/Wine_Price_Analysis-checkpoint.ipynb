# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xls = pd.ExcelFile('FirstGrowth_SecondWines.xlsx')
wine_name = xls.sheet_names
code_name = ['wine'+str(i) for i in range(11)]
for i,val in enumerate(wine_name):
    
    code_name[i] = pd.read_excel(xls,val )

# %%
def file_formatting(sheet):
    #deep copy
    wine = sheet.copy()
    vintage = wine.pop('Vintage')
    release_date =  wine.pop('Release Date')
    date = wine.columns
    wine = wine.T
    wine.columns = vintage
    wine.index = pd.to_datetime(wine.index)
    
    return vintage, release_date , wine

# %%
vintage, release_date , wine = file_formatting(code_name[0])

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 134 entries, 2008-06-30 to 2019-07-31
# Data columns (total 11 columns):
# 2007    134 non-null float64
# 2008    124 non-null float64
# 2009    110 non-null float64
# 2010    97 non-null float64
# 2011    88 non-null float64
# 2012    76 non-null float64
# 2013    64 non-null float64
# 2014    51 non-null float64
# 2015    38 non-null float64
# 2016    26 non-null float64
# 2017    14 non-null float64
# dtypes: float64(11)
# memory usage: 12.6 KB

# %%
wine.describe()
# Out:
# Vintage         2007          2008          2009          2010         2011  \
# count     134.000000    124.000000    110.000000     97.000000    88.000000
# mean     5383.888060   6824.838710   8079.172727   7003.701031  4326.147727
# std      1499.391083   2345.667105   2299.869685   1317.917337   548.685232
# min      1900.000000   2098.000000   5700.000000   5300.000000  3250.000000
# 25%      4657.500000   5250.000000   6462.500000   5967.000000  3784.750000
# 50%      5691.000000   6397.500000   7363.000000   6832.000000  4396.000000
# 75%      6463.500000   7300.000000   7972.500000   7350.000000  4800.000000
# max      8150.000000  14250.000000  14500.000000  11950.000000  5350.000000
#
# Vintage         2012         2013         2014         2015         2016  \
# count      76.000000    64.000000    51.000000    38.000000    26.000000
# mean     4020.105263  3839.781250  4117.156863  5063.710526  5865.923077
# std       687.420620   922.190275   830.507902   410.707360   173.442076
# min      3000.000000  2480.000000  2740.000000  4319.000000  5500.000000
# 25%      3331.500000  2945.250000  3120.000000  4742.500000  5710.250000
# 50%      3900.000000  3947.500000  4500.000000  5125.000000  5936.000000
# 75%      4727.500000  4812.250000  4833.000000  5308.500000  5985.000000
# max      5050.000000  5000.000000  5049.000000  5765.000000  6100.000000
#
# Vintage         2017
# count      14.000000
# mean     4782.285714
# std       111.243619
# min      4590.000000
# 25%      4694.750000
# 50%      4800.000000
# 75%      4900.000000
# max      4900.000000

# %%
import matplotlib.dates as mdates
wine.plot(figsize=(20,10), linewidth=3, fontsize=20,kind='line')
plt.xlabel('Year', fontsize=20)
plt.ylabel('Pounds', fontsize=20)
# Out:
# Text(0, 0.5, 'Pounds')

# %%
plt.plot(wine[2017])
plt.plot(wine[2013])
plt.show()

# %%
corr = wine.corr()

# %%
ax = sns.heatmap(corr,cmap='YlGnBu',annot=True)
ax.invert_yaxis()

# %%
corr
# Out:
# Vintage      2007      2008      2009      2010      2011      2012      2013  \
# Vintage
# 2007     1.000000  0.806066  0.741840  0.824834  0.942550  0.962302  0.968652
# 2008     0.806066  1.000000  0.942233  0.885829  0.921805  0.964836  0.965947
# 2009     0.741840  0.942233  1.000000  0.955310  0.816872  0.736091  0.900780
# 2010     0.824834  0.885829  0.955310  1.000000  0.877251  0.881562  0.954969
# 2011     0.942550  0.921805  0.816872  0.877251  1.000000  0.953030  0.972492
# 2012     0.962302  0.964836  0.736091  0.881562  0.953030  1.000000  0.988049
# 2013     0.968652  0.965947  0.900780  0.954969  0.972492  0.988049  1.000000
# 2014     0.977314  0.979194  0.929979  0.978157  0.972257  0.983585  0.973126
# 2015     0.820441  0.830125  0.647191  0.851959  0.901676  0.913360  0.928899
# 2016     0.686459  0.449888 -0.351240  0.716407  0.662424  0.778400  0.830201
# 2017     0.213790  0.052870  0.213917 -0.185584  0.140639  0.662498  0.277750
#
# Vintage      2014      2015      2016      2017
# Vintage
# 2007     0.977314  0.820441  0.686459  0.213790
# 2008     0.979194  0.830125  0.449888  0.052870
# 2009     0.929979  0.647191 -0.351240  0.213917
# 2010     0.978157  0.851959  0.716407 -0.185584
# 2011     0.972257  0.901676  0.662424  0.140639
# 2012     0.983585  0.913360  0.778400  0.662498
# 2013     0.973126  0.928899  0.830201  0.277750
# 2014     1.000000  0.887930  0.679478  0.216960
# 2015     0.887930  1.000000  0.611426  0.425146
# 2016     0.679478  0.611426  1.000000 -0.103415
# 2017     0.216960  0.425146 -0.103415  1.000000

# %%
#first-order differences; removing the trend may reveal correlation in seasonality.
wine.diff().plot(figsize=(20,10), linewidth=2, fontsize=20)
